# %%
import pickle
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# %%
modeldir = 'media/models/0c7a3d76-beee-41f5-952a-993d725f3838.pkl'

with open(modeldir, 'rb') as handle:
        model_file = pickle.load(handle)

# %%
model_file['test_data_ids']
# Out:
# [267,
#  270,
#  313,
#  315,
#  316,
#  320,
#  325,
#  356,
#  358,
#  369,
#  370,
#  373,
#  399,
#  404,
#  406,
#  435,
#  452,
#  456,
#  462,
#  465]

# %%
train_df = model_file['train_data']
train_data = train_df.copy()
X_train = train_data.loc[:, ~train_data.columns.isin(['id', 'kelas'])]

# %%
X_train
# Out:
#      form_factor  aspect_ratio     rect  narrow_factor      prd      plw  \
# 1        0.46806       3.06126  1.29403        0.56693  4.59197  1.96233
# 2        0.56187       2.71795  1.28121        0.60468  4.19113  1.85265
# 4        0.38458       1.86635  1.59125        0.65477  5.06588  2.15977
# 5        0.43070       3.73281  1.28494        0.51522  4.78701  1.94526
# 6        0.30448       3.26391  1.71611        0.47677  5.69340  2.07785
# ..           ...           ...      ...            ...      ...      ...
# 195      0.57637       2.15672  1.28263        0.67843  4.13808  1.91807
# 196      0.60319       2.29392  1.28127        0.65818  4.04505  1.85411
# 197      0.60426       2.21608  1.47522        0.62407  4.04146  1.73792
# 198      0.64401       2.25597  1.27910        0.66426  3.91474  1.80174
# 199      0.45547       3.41818  1.44379        0.50793  4.65503  1.82928
#
#          idm  entropy      asm   contrast  correlation
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(X_train)
# Out:
#      form_factor  aspect_ratio     rect  narrow_factor      prd      plw  \
# 1        0.46806       3.06126  1.29403        0.56693  4.59197  1.96233
# 2        0.56187       2.71795  1.28121        0.60468  4.19113  1.85265
# 4        0.38458       1.86635  1.59125        0.65477  5.06588  2.15977
# 5        0.43070       3.73281  1.28494        0.51522  4.78701  1.94526
# 6        0.30448       3.26391  1.71611        0.47677  5.69340  2.07785
# 7        0.45179       2.19735  1.53228        0.61495  4.67390  1.97527
# 8        0.48028       3.48384  1.28120        0.53409  4.53316  1.88116
# 9        0.54409       2.61519  1.28662        0.61515  4.25908  1.89525
# 10       0.44435       3.56454  1.28326        0.52759  4.71289  1.94173
# 11       0.54740       1.20827  1.40186        0.86700  4.24616  2.01433
# 12       0.68695       1.59726  1.35313        0.76753  3.79042  1.78914
# 13       0.58041       1.42546  1.37237        0.80675  4.12365  1.95517
# ...

# %%
X_train

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
scaler.transform([[0.5257,2.8663,1.2826,0.5885,4.333,1.8904,0.5926,5.2905,0.0129,75.6403,0.0004]])
# Out:
# array([[ 6.49393764e-01,  2.58552689e-01,  2.97757870e-03,
#          5.17741186e-01,  1.28122140e-01,  4.30640189e-01,
#          3.59498980e+00, -9.58002538e-02,  2.14754098e+00,
#          1.51557706e-01,  2.70270270e-01]])
